# %% [markdown]
# # Exploratory Data Analysis
#
# TODO(Input):
# - In  this project we are going to  analyse zomato data set the data set was taken from kaggle
# - First we are going to clean the data and analyse the data and understand the key metrics
#   atlast we are going to visulaize the data set
# - We are going to use python and some of its famous data science libraries

# %%
# Importing all the libraries

import pandas as pd
import numpy as np
import opendatasets as od
import  matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import matplotlib

# %%
# way to download data dircty from  kaggle

download_url = 'https://www.kaggle.com/datasets/sobhanmoosavi/zomato'
od.download(download_url)

# %%
# reading the data set

path = r'D:\Zomatodataset\zomato.csv'
df = pd.read_csv(path, encoding = 'latin-1')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.shape
# Out:
# (9551, 21)

# %%
# getting total info about the data set
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
# Describing the Categorical and numerical value in a dataset

df.describe(include = 'all')
# Out:
#         Restaurant ID  Restaurant Name  Country Code       City  \
# count    9.551000e+03             9551   9551.000000       9551
# unique            NaN             7446           NaN        141
# top               NaN  Cafe Coffee Day           NaN  New Delhi
# freq              NaN               83           NaN       5473
# mean     9.051128e+06              NaN     18.365616        NaN
# std      8.791521e+06              NaN     56.750546        NaN
# min      5.300000e+01              NaN      1.000000        NaN
# 25%      3.019625e+05              NaN      1.000000        NaN
# 50%      6.004089e+06              NaN      1.000000        NaN
# 75%      1.835229e+07              NaN      1.000000        NaN
# max      1.850065e+07              NaN    216.000000        NaN
#
#                            Address         Locality  \
# count                         9551             9551
# unique                        8918             1208
# ...

# %%
# Finding null values

df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# getting the columns with null values
for features in df.columns:
    if df[features].isnull().sum()>0:
        print(features)
# Out:
# Cuisines

# %%
y = df.isnull()
y
# Out:
#       Restaurant ID  Restaurant Name  Country Code   City  Address  Locality  \
# 0             False            False         False  False    False     False
# 1             False            False         False  False    False     False
# 2             False            False         False  False    False     False
# 3             False            False         False  False    False     False
# 4             False            False         False  False    False     False
# ...             ...              ...           ...    ...      ...       ...
# 9546          False            False         False  False    False     False
# 9547          False            False         False  False    False     False
# 9548          False            False         False  False    False     False
# 9549          False            False         False  False    False     False
# 9550          False            False         False  False    False     False
#
# ...

# %%
for features in y.columns:
    print(features)
    print(y[features].value_counts())
# Out:
# Restaurant ID
# False    9551
# Name: Restaurant ID, dtype: int64
# Restaurant Name
# False    9551
# Name: Restaurant Name, dtype: int64
# Country Code
# False    9551
# Name: Country Code, dtype: int64
# City
# False    9551
# Name: City, dtype: int64
# Address
# False    9551
# Name: Address, dtype: int64
# Locality
# False    9551
# Name: Locality, dtype: int64
# Locality Verbose
# False    9551
# Name: Locality Verbose, dtype: int64
# Longitude
# False    9551
# Name: Longitude, dtype: int64
# Latitude
# False    9551
# Name: Latitude, dtype: int64
# Cuisines
# False    9542
# True        9
# Name: Cuisines, dtype: int64
# Average Cost for two
# False    9551
# Name: Average Cost for two, dtype: int64
# Currency
# False    9551
# Name: Currency, dtype: int64
# Has Table booking
# False    9551
# Name: Has Table booking, dtype: int64
# Has Online delivery
# False    9551
# Name: Has Online delivery, dtype: int64
# Is delivering now
# False    9551
# ...

# %%
# visulaising nan value

sns.heatmap(df.isnull(), yticklabels= False, cbar = False, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Importing another data set that contains country with the operation of zomato

# %%
df_country = pd.read_excel(r'D:\Zomatodataset\Country-Code.xlsx')
df_country
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %% [markdown]
# # Merging two dataset

# %%
final_df= pd.merge(df,df_country, on='Country Code', how = 'left')
final_df.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...  Has Table booking Has Online delivery  \
# 0  French, Japanese, Desserts  ...                Yes                  No
# 1                    Japanese  ...                Yes                  No
#
# ...

# %%
final_df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
final_df['Country'].value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
country_name = final_df['Country'].value_counts().index
country_name
# Out:
# Index(['India', 'United States', 'United Kingdom', 'Brazil', 'UAE',
#        'South Africa', 'New Zealand', 'Turkey', 'Australia', 'Phillipines',
#        'Indonesia', 'Singapore', 'Qatar', 'Sri Lanka', 'Canada'],
#       dtype='object')

# %%
country_value = final_df['Country'].value_counts().values
country_value
# Out:
# array([8652,  434,   80,   60,   60,   60,   40,   34,   24,   22,   21,
#          20,   20,   20,    4], dtype=int64)

# %% [markdown]
# # Finding Top 5 countries with highest transaction

# %%
df= pd.DataFrame(country_value, country_name)
df.rename(columns = {0: 'value'})[0:5]
# Out:
#                 value
# India            8652
# United States     434
# United Kingdom     80
# Brazil             60
# UAE                60

# %%
plt.pie(country_value[:3], labels= country_name[:3], autopct = "'%0.1f%%'")
# Out:
# ([<matplotlib.patches.Wedge at 0x29a30a9be50>,
# ...
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')],
#  [Text(-0.590713238233751, 0.10515640815183668, "'94.4%'"),
#   Text(0.5876082086391032, -0.12131196618612707, "'4.7%'"),
#   Text(0.5997744629358018, -0.01644972978715676, "'0.9%'")])

# %% [markdown]
# ## Grouping and finding relation between variables

# %%
ratings = final_df.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %%
matplotlib.rcParams['figure.figsize'] =(10,6)
sns.barplot(x='Aggregate rating', y = 'Rating Count', data =ratings)
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
bins = np.linspace(0,5, 6)
group_name = ['not rated','poor','average','good','excellent']
ratings['ratings'] = pd.cut(ratings['Aggregate rating'], bins, labels = group_name, include_lowest = True)
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count    ratings
# 0                0.0        White   Not rated          2148  not rated
# 1                1.8          Red        Poor             1       poor
# 2                1.9          Red        Poor             2       poor
# 3                2.0          Red        Poor             7       poor
# 4                2.1          Red        Poor            15    average
# 5                2.2          Red        Poor            27    average
# 6                2.3          Red        Poor            47    average
# 7                2.4          Red        Poor            87    average
# 8                2.5       Orange     Average           110    average
# 9                2.6       Orange     Average           191    average
# 10               2.7       Orange     Average           250    average
# 11               2.8       Orange     Average           315    average
# ...

# %%
matplotlib.rcParams['figure.figsize'] =(10,4)
sns.countplot(x='ratings', data =ratings)
# Out:
# <AxesSubplot:xlabel='ratings', ylabel='count'>

# %% [markdown]
# # Country with low rating

# %%
ratings = final_df.groupby(['Country','Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})
ratings[ratings['Aggregate rating']<1]
# Out:
#             Country  Aggregate rating Rating color Rating text  Rating Count
# 12           Brazil               0.0        White   Not rated             5
# 37            India               0.0        White   Not rated          2139
# 180  United Kingdom               0.0        White   Not rated             1
# 200   United States               0.0        White   Not rated             3

# %% [markdown]
# # Finding the currency of each country

# %%
final_df[['Country', 'Currency']].groupby(['Country', 'Currency']).size().reset_index().rename(columns={0:'Total_count'})
# Out:
#            Country                Currency  Total_count
# 0        Australia               Dollar($)           24
# 1           Brazil      Brazilian Real(R$)           60
# 2           Canada               Dollar($)            4
# 3            India      Indian Rupees(Rs.)         8652
# 4        Indonesia  Indonesian Rupiah(IDR)           21
# 5      New Zealand           NewZealand($)           40
# 6      Phillipines        Botswana Pula(P)           22
# 7            Qatar         Qatari Rial(QR)           20
# 8        Singapore               Dollar($)           20
# 9     South Africa                 Rand(R)           60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)           20
# 11          Turkey        Turkish Lira(TL)           34
# 12             UAE      Emirati Diram(AED)           60
# 13  United Kingdom              Pounds(£)           80
# 14   United States               Dollar($)          434

# %% [markdown]
# #Country with most Online Transaction

# %%
final_df[final_df['Has Online delivery'] == 'No'].Country.value_counts()
# Out:
# India             6229
# United States      434
# United Kingdom      80
# Brazil              60
# South Africa        60
# New Zealand         40
# Turkey              34
# UAE                 32
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %% [markdown]
# # Most Favourite Cuisines

# %%
final_df['Cuisines'].value_counts().head(10)
# Out:
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: Cuisines, dtype: int64
